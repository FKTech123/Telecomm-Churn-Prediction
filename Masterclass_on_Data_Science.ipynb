# %%
10+30
# Out:
# 40

# %%
x = 10
y = 20

z = x+y

# %%
z
# Out:
# 30

# %%
x
# Out:
# 10

# %%
y
# Out:
# 20

# %%
x, y = y,x

# %%
print(x)
print(y)
# Out:
# 20
# 10

# %%
if x == 20:
  print("hahahahahahah")
else:
  print ("BYE BYE")
# Out:
# hahahahahahah

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/telecom_churn 5.csv')

# %%
df
# Out:
#       Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# 0         0           128                1         1       2.70
# 1         0           107                1         1       3.70
# 2         0           137                1         0       0.00
# 3         0            84                0         0       0.00
# 4         0            75                0         0       0.00
# ...     ...           ...              ...       ...        ...
# 3328      0           192                1         1       2.67
# 3329      0            68                1         0       0.34
# 3330      0            28                1         0       0.00
# 3331      0           184                0         0       0.00
# 3332      0            74                1         1       3.70
#
#       CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0                 1    265.1       110           89.0        9.87      10.0
# ...

# %%
df.head(10)
# Out:
#    Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  CustServCalls  \
# 0      0           128                1         1       2.70              1
# 1      0           107                1         1       3.70              1
# 2      0           137                1         0       0.00              0
# 3      0            84                0         0       0.00              2
# 4      0            75                0         0       0.00              3
# 5      0           118                0         0       0.00              0
# 6      0           121                1         1       2.03              3
# 7      0           147                0         0       0.00              0
# 8      0           117                1         0       0.19              1
# 9      0           141                0         1       3.02              0
#
#    DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0    265.1       110           89.0        9.87      10.0
# ...

# %%
df.tail(10)
# Out:
#       Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  \
# 3323      1           117                1         0       0.39
# 3324      0           159                1         0       0.00
# 3325      0            78                1         0       0.23
# 3326      0            96                1         0       0.36
# 3327      0            79                1         0       0.00
# 3328      0           192                1         1       2.67
# 3329      0            68                1         0       0.34
# 3330      0            28                1         0       0.00
# 3331      0           184                0         0       0.00
# 3332      0            74                1         1       3.70
#
#       CustServCalls  DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 3323              5    118.4       126           45.9       12.47      13.6
# 3324              1    169.8       114           46.0        9.89      11.6
# ...

# %%
df.describe()
# Out:
#              Churn  AccountWeeks  ContractRenewal     DataPlan    DataUsage  \
# count  3333.000000   3333.000000      3333.000000  3333.000000  3333.000000
# mean      0.144914    101.064806         0.903090     0.276628     0.816475
# std       0.352067     39.822106         0.295879     0.447398     1.272668
# min       0.000000      1.000000         0.000000     0.000000     0.000000
# 25%       0.000000     74.000000         1.000000     0.000000     0.000000
# 50%       0.000000    101.000000         1.000000     0.000000     0.000000
# 75%       0.000000    127.000000         1.000000     1.000000     1.780000
# max       1.000000    243.000000         1.000000     1.000000     5.400000
#
#        CustServCalls      DayMins     DayCalls  MonthlyCharge   OverageFee  \
# count    3333.000000  3333.000000  3333.000000    3333.000000  3333.000000
# mean        1.562856   179.775098   100.435644      56.305161    10.051488
# ...

# %%
import seaborn as sbn

# %%
sbn.boxplot(x='Churn', y='CustServCalls', data =df)
# Out:
# <Axes: xlabel='Churn', ylabel='CustServCalls'>

# %%
sbn.boxplot(x='Churn', y='MonthlyCharge', data =df)
# Out:
# <Axes: xlabel='Churn', ylabel='MonthlyCharge'>

# %%
sbn.boxplot(x='Churn', y='OverageFee', data =df)
# Out:
# <Axes: xlabel='Churn', ylabel='OverageFee'>

# %%
sbn.scatterplot(x='MonthlyCharge', y ='OverageFee', data =df, hue = 'Churn')
# Out:
# <Axes: xlabel='MonthlyCharge', ylabel='OverageFee'>

# %%
sbn.scatterplot(x='MonthlyCharge', y ='OverageFee', data =df, hue = 'DataPlan')
# Out:
# <Axes: xlabel='MonthlyCharge', ylabel='OverageFee'>

# %%
sbn.boxplot(x='Churn', y='AccountWeeks', data =df)
# Out:
# <Axes: xlabel='Churn', ylabel='AccountWeeks'>

# %%
#import matplotlib.pyplot as plt
#plt.figure(figsize=(10,8))


sbn.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >
